# %%
# Humanクラスの定義
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 大人かどうかを判定して出力するメソッド
    def check_adult(self):
        if self.age >= 20:
            print(f"{self.name}さんは{self.age}歳なので、大人です。")
        else:
            print(f"{self.name}さんは{self.age}歳なので、大人ではありません。")

# インスタンスを複数生成してリストに追加
human_list = [
    Human("侍太郎", 25),
    Human("侍花子", 18),
    Human("侍一郎", 20),
    Human("侍二郎", 15)
]

# リストの要素数分だけcheck_adultメソッドを呼び出す
for human in human_list:
    human.check_adult()
# Out:
# 侍太郎さんは25歳なので、大人です。
# 侍花子さんは18歳なので、大人ではありません。
# 侍一郎さんは20歳なので、大人です。
# 侍二郎さんは15歳なので、大人ではありません。
